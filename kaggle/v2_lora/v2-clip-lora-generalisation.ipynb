# %% [markdown]
# # V2-8 CLIP LoRA generalisation (private)
# Frozen OpenAI CLIP ViT-B/16 + LoRA (last 4 blocks) + MLP-B. NTIRE locked.

# %%
import runpy
runpy.run_path('train_v2_clip_lora.py', run_name='__main__')
